# %% [markdown]
# # GRIP - The Sparks Foundation
# # Task - Exploratory Data Analysis - Retail
#
#
# ## Dataset- Sample Superstore
#
#
# This dataset is about the sale and the profit earned by a Sample store in the US.

# %% [markdown]
# ### Lets first import all the essentials library and the instances.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading the Data

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# ### Following set of code is about the general information about the data:

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# The above output gives good information about the dataset, in this analysis I mainly foccused on the Sales and Profit and thier trend with various aspects.

# %%
df.loc[df.Profit==8399.976000]
# Out:
#            Ship Mode    Segment        Country       City    State  \
# 6826  Standard Class  Corporate  United States  Lafayette  Indiana
#
#       Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 6826        47905  Central  Technology      Copiers  17499.95         5
#
#       Discount    Profit
# 6826       0.0  8399.976

# %%
df.loc[df.Profit==-6599.978]
# Out:
#            Ship Mode   Segment        Country       City State  Postal Code  \
# 7772  Standard Class  Consumer  United States  Lancaster  Ohio        43130
#
#      Region    Category Sub-Category     Sales  Quantity  Discount    Profit
# 7772   East  Technology     Machines  4499.985         5       0.7 -6599.978

# %% [markdown]
# The above outputs clearly tell that the Lafayette city of US had the maximum profit and a sale of 17499.95 and the maximum loss with the sale of 4499.985 was of  Lancaster city of the US.

# %% [markdown]
# ### Lets sort the dataset by the Profit gained, and take a look at the first few rows of the sorted dataset.

# %%
df.sort_values('Profit', ascending=False, inplace = True)

# %%
df.head(15)
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 8153     First Class     Consumer  United States        Seattle    Washington
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 9039  Standard Class     Consumer  United States        Detroit      Michigan
# 4098  Standard Class     Consumer  United States    Minneapolis     Minnesota
# 2623     First Class  Home Office  United States  New York City      New York
# 509   Standard Class     Consumer  United States        Atlanta       Georgia
# 8488    Second Class     Consumer  United States      Arlington      Virginia
# 7666  Standard Class  Home Office  United States     Providence  Rhode Island
# 6520    Second Class     Consumer  United States        Jackson      Michigan
# 1085  Standard Class     Consumer  United States        Yonkers      New York
# 4277  Standard Class    Corporate  United States       Lakewood    New Jersey
# 8990  Standard Class    Corporate  United States    Springfield      Missouri
# 6626  Standard Class     Consumer  United States  New York City      New York
# 8204        Same Day    Corporate  United States  New York City      New York
#
#       Postal Code   Region         Category Sub-Category      Sales  Quantity  \
# 6826        47905  Central       Technology      Copiers  17499.950         5
# 8153        98115     West       Technology      Copiers  13999.960         4
# 4190        19711     East       Technology      Copiers  10499.970         3
# 9039        48205  Central  Office Supplies      Binders   9892.740        13
# 4098        55407  Central  Office Supplies      Binders   9449.950         5
# 2623        10024     East       Technology      Copiers  11199.968         4
# 509         30318    South  Office Supplies      Binders   6354.950         5
# 8488        22204    South       Technology     Machines   8749.950         5
# 7666         2908     East       Technology      Copiers   5399.910         9
# 6520        49201  Central  Office Supplies      Binders   5443.960         4
# 1085        10701     East       Technology     Machines   4899.930         7
# 4277         8701     East       Technology     Machines   9099.930         7
# 8990        65807  Central       Technology      Copiers   4899.930         7
# 6626        10024     East       Technology     Machines   6999.960         4
# 8204        10024     East       Technology     Machines   4643.800         4
#
#       Discount     Profit
# 6826       0.0  8399.9760
# 8153       0.0  6719.9808
# 4190       0.0  5039.9856
# 9039       0.0  4946.3700
# 4098       0.0  4630.4755
# 2623       0.2  3919.9888
# 509        0.0  3177.4750
# 8488       0.0  2799.9840
# 7666       0.0  2591.9568
# 6520       0.0  2504.2216
# 1085       0.0  2400.9657
# 4277       0.0  2365.9818
# 8990       0.0  2302.9671
# 6626       0.0  2239.9872
# 8204       0.0  2229.0240

# %% [markdown]
# ## Cleaning the Data, i.e, removing the columns which are not required in this analysis.
# The Country column has only one value(US), so we can drop that column. Also, the analysis was done on the regions and state, thus, City and Postal Column is also of no use to us.

# %%
df_state =df.drop(['Country','City','Postal Code'], axis=1)

# %%
df_state
# Out:
#            Ship Mode      Segment           State   Region         Category  \
# 6826  Standard Class    Corporate         Indiana  Central       Technology
# 8153     First Class     Consumer      Washington     West       Technology
# 4190  Standard Class     Consumer        Delaware     East       Technology
# 9039  Standard Class     Consumer        Michigan  Central  Office Supplies
# 4098  Standard Class     Consumer       Minnesota  Central  Office Supplies
# ...              ...          ...             ...      ...              ...
# 4991  Standard Class    Corporate        Illinois  Central  Office Supplies
# 3011  Standard Class  Home Office        Colorado     West       Technology
# 9774  Standard Class     Consumer           Texas  Central  Office Supplies
# 683         Same Day    Corporate  North Carolina    South       Technology
# 7772  Standard Class     Consumer            Ohio     East       Technology
#
#      Sub-Category      Sales  Quantity  Discount     Profit
# 6826      Copiers  17499.950         5       0.0  8399.9760
# 8153      Copiers  13999.960         4       0.0  6719.9808
# 4190      Copiers  10499.970         3       0.0  5039.9856
# 9039      Binders   9892.740        13       0.0  4946.3700
# 4098      Binders   9449.950         5       0.0  4630.4755
# ...           ...        ...       ...       ...        ...
# 4991      Binders   1889.990         5       0.8 -2929.4845
# 3011     Machines   2549.985         5       0.7 -3399.9800
# 9774      Binders   2177.584         8       0.8 -3701.8928
# 683      Machines   7999.980         4       0.5 -3839.9904
# 7772     Machines   4499.985         5       0.7 -6599.9780
#
# [9994 rows x 10 columns]

# %% [markdown]
# ### Checking if there is any null value present in the dataset.

# %%
df_state.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### ANALYSIS of the Data
#
#
#
# This can be done in major three ways:
# 1. Product Level Analysis(Category and Sub-Category wise)
# 2. Region Level Analysis
# 3. Customer Level Analysis

# %% [markdown]
# ### Lets start with the Product level Analysis.
# Broadly, it is divide into two major domains- Category and Sub-Category.
#
#
#
# Lets, first check what are the unique Categories in the dataset, plotting the same with Number of such products by counting the respective values.

# %%
df_state['Category'].unique()
# Out:
# array(['Technology', 'Office Supplies', 'Furniture'], dtype=object)

# %%
df_state['Category'].value_counts().plot(kind='bar', figsize=(5,5))
plt.title('Category wise Distribution')
plt.xlabel('Categories')
plt.ylabel('No. of products')
plt.show()

# %% [markdown]
# With the above plot, we can easily conclude the highest number of products sold from the supermarket was of the Office Suppliers Category.
# Let's now check which sub category had the highest sale.
#
# For that we need to know what are the unique Sub-Categories present in the Dataset.

# %%
df_state['Sub-Category'].unique()
# Out:
# array(['Copiers', 'Binders', 'Machines', 'Phones', 'Bookcases',
#        'Accessories', 'Appliances', 'Storage', 'Chairs', 'Tables',
#        'Furnishings', 'Labels', 'Paper', 'Supplies', 'Envelopes', 'Art',
#        'Fasteners'], dtype=object)

# %%
a=df_state['Sub-Category'].value_counts()

# %%
a.plot.pie(autopct="%1.1f%%",figsize=(10,10))
plt.title('Distribution of Sub-Categotries')
plt.show()

# %% [markdown]
# This can be clearly seen, the Copiers and Machines have the least number of products sold where as Papers and Binders had the highest Number of products sold.
#
#
#
# Now, to have even more clear picture, lets now plot the Sub-Categories inside each Category with the Sales and Profit Gained.

# %%
df_c1= df_state.loc[df_state['Category']=='Office Supplies']
df_c2=df_state.loc[df_state['Category']=='Furniture']
df_c3=df_state.loc[df_state['Category']=='Technology']
a=df_c1.groupby('Sub-Category')[['Sales','Profit']].agg(['sum'])
b=df_c2.groupby('Sub-Category')[['Sales','Profit']].agg(['sum'])
c=df_c3.groupby('Sub-Category')[['Sales','Profit']].agg(['sum'])

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,3,1)
ax1=fig.add_subplot(1,3,2)
ax2=fig.add_subplot(1,3,3)

a.plot(kind='bar', ax=ax0,figsize=(8,8))
ax0.set_title('Office Supplies')
ax0.set_xlabel('sub-Category')
ax0.set_ylabel('Sales and Profit')
b.plot(kind='bar', ax=ax1,figsize=(8,8))
ax1.set_title('Furniture')
ax1.set_xlabel('sub-Category')
ax1.set_ylabel('Sales and Profit')
c.plot(kind='bar', ax=ax2,figsize=(8,8))
ax2.set_title('Technology')
ax2.set_xlabel('sub-Category')
ax2.set_ylabel('Sales and Profit')
fig.tight_layout()                  
plt.show()

# %% [markdown]
# As per the above plot, it is well understood that the sale of Fasteners was least among all the three Sub-Categories, and that of Chairs and Phones were highest and the profit from Copiers is highest among all, where as the loss by Tables is highest.

# %% [markdown]
# ### Lets now work on the State and Region Level Analysis.
#
#
# First of all, check how the Sale Trend goes with respect to the State.

# %%
df_state.groupby('State')[['State','Sales']].agg(['sum']).plot(kind='bar',figsize=(20,5))
plt.ylabel('Sale')
plt.title('Sale in various States')
plt.show()

# %% [markdown]
# The highest sale was in California and New york, the Texas and Washington had the moderate Sale and the other state had comparably low Sale.

# %%
df_state.groupby('State')[['State','Profit']].agg(['sum']).plot(kind='bar',figsize=(20,8),color='g');
plt.ylabel('Profit or Gain')
plt.title('Profit made by the Superstore in various States')
plt.show()

# %% [markdown]
# The Sale and Profit are directly propotional to each other, the same can be seem here, the States with the highest sale i.e., California and New york shows the cities where the Supermarket earned the highest Profit. The Texas being an exception case shows a higher loss and Washington also had a good profit when compared to the other states.

# %% [markdown]
# Lets now see the Sale and Profit Trend with respect to the different regions in the Country.

# %%
df_state.groupby('Region')[['Region','Sales']].agg(['sum']).plot(kind='bar',figsize=(20,5))
plt.ylabel('Sale')
plt.title('Sale in various Regions')
plt.show()

# %%
df_state.groupby('Region')[['Region','Profit']].agg(['sum']).plot(kind='bar',figsize=(20,5),color='y')
plt.ylabel('Profit or Gain')
plt.title('Profit made by the Superstore in various Regions')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x="Sub-Category", hue="Region", data=df_state)
plt.title('Distrubution of sub-categories Region wise')
plt.show()

# %% [markdown]
# With above three plots, the inference be taken out the West Region of the Country is the region where supermarket had the highest as well as profit, the central region had more sale then Souhtern region but had lesser Profit from it.

# %% [markdown]
# ### Lets now work on the Segment or Consumer Level Analysis.
#
#
# We have to check how the Sale and Profit trend goes with Segment.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)
df_state.groupby('Segment')[['Segment','Sales']].agg(['sum']).plot(kind='bar',ax=ax0,figsize=(10,5),color = 'b');
ax0.set_title('Segment V/S Sales')
ax0.set_xlabel('Segment')
ax0.set_ylabel('Sales')
df_state.groupby('Segment')[['Segment','Profit']].agg(['sum']).plot(kind='bar',ax=ax1,figsize=(10,5), color='r');
ax1.set_title('Segment V/S ')
ax1.set_xlabel('Segment')
ax1.set_ylabel('Profit')
fig.tight_layout()
plt.show()

# %% [markdown]
# The Consumer domain of the Segment had the highest Sale as well as the profit and home office had the least.

# %% [markdown]
# ### Conclusion
# We have seen the analysis at various level, and at every level we found that there are various areas where we can work to make more profit.

# %% [markdown]
# # By - Vedangi Sharma
